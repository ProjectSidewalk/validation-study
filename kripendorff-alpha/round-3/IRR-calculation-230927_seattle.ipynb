# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point
# %matplotlib inline
import seaborn as sns; sns.set_theme(color_codes=True)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors
import warnings
warnings.filterwarnings('ignore')
from scipy import stats
import math    
import folium
from scipy.cluster.hierarchy import linkage, fcluster
from scipy.spatial.distance import pdist
import sys
from haversine import haversine
from shapely.geometry import LineString
from shapely.ops import split, linemerge
import krippendorff

# %%
import sys
sys.path.append('../')

from src.cluster import *
from src.colors import *
from src.map import *
from src.compare import *

# %% [markdown]
# ## Krippendorff's alpha

# %%
#read in seattle validation labels
seattle_labels = gpd.read_file('data/round-3/seattle-validation-labels-round3-230927.geojson')
seattle_labels = seattle_labels.drop(columns=['time_created'])
seattle_labels.head()
# Out:
#        username  label_id  street_edge_id neighborhood      label_type  \
# 0  Devon Snyder      8263             519    Greenwood        Obstacle
# 1  Devon Snyder      8264             519    Greenwood        Obstacle
# 2  Devon Snyder      8265             519    Greenwood  SurfaceProblem
# 3  Devon Snyder      8266             519    Greenwood        Obstacle
# 4  Devon Snyder      8267             519    Greenwood  SurfaceProblem
#
#          lat         lng         gsv_panorama_id correct  severity temporary  \
# 0  47.697910 -122.346878  eA8O01ruC7m2Hxna2rOYmA    None         5         t
# 1  47.697910 -122.346840  eA8O01ruC7m2Hxna2rOYmA    None         5         t
# 2  47.697731 -122.347191  u54hhkI1_JMvO6PSVuls_Q    None         1         f
# 3  47.697914 -122.346817  -bwvo2vUzCb2YOsT0bKDGQ    None         5         t
# 4  47.697880 -122.346687  -bwvo2vUzCb2YOsT0bKDGQ    None         1         f
#
#         tag_list description                     geometry
# 0           sign        None  POINT (-122.34688 47.69791)
# 1           sign        None  POINT (-122.34684 47.69791)
# 2         cracks        None  POINT (-122.34719 47.69773)
# 3           sign        None  POINT (-122.34682 47.69791)
# 4  utility panel        None  POINT (-122.34669 47.69788)

# %%
#count the cluster numbers for each label type
def count_clusters(labels, label_type_id):
    df = cluster_label_type_at_index(labels,label_type_id)[2]
    df["clustered"] = df.duplicated(subset="cluster_id", keep=False)
    df1 = df[df['clustered'] == True]
    return df1.cluster_id.nunique()

# %%
cluster_count_seattle = {}
for i in [2,4,5]:
    clusters =  count_clusters(seattle_labels, i)
    cluster_count_seattle[label_types[i]] = clusters

# %%
cluster_count_seattle
# Out:
# {'Problem': 291, 'SurfaceProblem': 259, 'Obstacle': 16}

# %%
#count the numbers for eanch label type
seattle_labels.label_type.value_counts()
# Out:
# SurfaceProblem    728
# Obstacle           80
# Name: label_type, dtype: int64

# %%
#read in seattle streets
seattle_streets = gpd.read_file("data/round-3/seattle-streets-230927.geojson")

# %%
#split line into segments of 30 ft
def split_line_at_intervals(line, interval=20):
    distance = 0
    segments = []

    while distance < line.length:
        sub_line = line.interpolate(distance)
        next_distance = distance + interval
        next_sub_line = line.interpolate(next_distance)
        segment = LineString([sub_line, next_sub_line])
        segments.append(segment)
        distance = next_distance

    return segments

def split_geodataframe(geodf, local_crs, interval=20):
    
    geodf = geodf.to_crs(local_crs)
    
    new_rows = []

    for index, row in geodf.iterrows():
        line = row.geometry
        splitted_lines = split_line_at_intervals(line, interval)

        for segment_id, segment in enumerate(splitted_lines):
            new_row = row.copy()
            new_row.geometry = segment
            new_row['segment_id'] = segment_id
            new_rows.append(new_row)

    df = gpd.GeoDataFrame(new_rows, columns=geodf.columns.append(pd.Index(['segment_id'])))
    #add a column that combines street_edge_id and segment_id
    df['street_edge_segment_id'] =  df['street_edge_id'].astype(str) + '_' +  df['segment_id'].astype(str)
    df.crs = local_crs
    return df

# %%
#obtain cluster to street segment mapping
def cluster_to_street_segment_mapping(df,streets_seg):
     # Group by cluster_id and combine all geometries in each group into a MultiPoint
     df_grouped = df.groupby('cluster_id')['geometry'].apply(lambda x: x.unary_union)
     # Calculate centroid of each group
     centroids = df_grouped.centroid
     # Convert centroids to GeoDataFrame
     cluster_centroids = gpd.GeoDataFrame(geometry=centroids).reset_index()
     cluster_centroids.crs = {'init' :'epsg:4326'}
     cluster_centroids_ft = cluster_centroids.to_crs(epsg=streets_seg.crs.to_epsg())
     #map gdf_centroids to seattle_split, delete index_right column
     cluster_centeroids_street = cluster_centroids_ft.sjoin_nearest(streets_seg, distance_col='distance')
     cluster_centeroids_street = cluster_centeroids_street.drop(columns=['index_right'])
     #select only cluster_id and street_edge_segment_id
     cluster_centeroids_street = cluster_centeroids_street[['cluster_id','street_edge_segment_id']]
     #if there are multiple street_edge_segment_ids for a cluster_id, select the first one
     cluster_centeroids_street = cluster_centeroids_street.groupby('cluster_id').first().reset_index()
     return cluster_centeroids_street

# %%
#construct agreement table
def irr_table (df,street_seg):
    mikey = df[df['username'] == 'mikey']
    devon = df[df['username'] == 'Devon Snyder']
    irr_mikey = mikey.merge(street_seg, on='street_edge_segment_id', how='right').fillna(0)
    irr_devon = devon.merge(street_seg, on='street_edge_segment_id', how='right').fillna(0)
    #replace usernames with 1
    irr_mikey  = irr_mikey .replace('mikey',1)
    irr_devon  = irr_devon .replace('Devon Snyder',1)
    #group by street_edge_segment_id and count the number of label_ids
    irr_mikey = irr_mikey.groupby('street_edge_segment_id').sum()
    irr_devon = irr_devon.groupby('street_edge_segment_id').sum()
    irr_mikey = irr_mikey[['username']].reset_index()
    irr_devon = irr_devon[['username']].reset_index()
    irr_mikey = irr_mikey.rename(columns={'username':'mikey'})
    irr_devon = irr_devon.rename(columns={'username':'devon'})
    irr_mikey_devon = irr_mikey.merge(irr_devon, on='street_edge_segment_id', how='left').fillna(0)
    irr_mikey_devon = irr_mikey_devon.drop(columns=['street_edge_segment_id'])
    
    return irr_mikey_devon

# %%
#calculate krippendorff's alpha
def krippendorff_alpha(labels,label_type_id, streets, local_crs):
    #clustering by label type
    label_type = cluster_label_type_at_index(labels,label_type_id)[2]
    #split streets into segments
    street_seg = split_geodataframe(streets, local_crs, interval=30)
    #map cluster_id to street_edge_segment_id
    mapping = cluster_to_street_segment_mapping(label_type,street_seg)
    #update the street_edge_segment_id with the one closest to the cluster centroid
    label_type = label_type.merge(mapping, on='cluster_id', how='left')
    #select only the columns we need
    df = label_type[['username','cluster_id','street_edge_segment_id','label_id']]
    #construct agreement table
    irr = irr_table(df,street_seg)
    data_matrix = irr.T.to_numpy()
    alpha = krippendorff.alpha(data_matrix,level_of_measurement='ratio')

    return alpha.round(3)

# %%
alpha_seattle = {}
for i in [2,4,5]:
    alpha = krippendorff_alpha(seattle_labels,i, seattle_streets, 2285)
    alpha_seattle[label_types[i]] = alpha

# %%
#30 ft segments
alpha_seattle
# Out:
# {'Problem': 0.661, 'SurfaceProblem': 0.66, 'Obstacle': 0.389}

# %% [markdown]
# ### surface problem and obstacle for severity level > = 4

# %%
#take out label type = surfaceproblem and obstacle
seattle_problems= seattle_labels[(seattle_labels['label_type'] == 'SurfaceProblem') | (seattle_labels['label_type'] == 'Obstacle') ]
#select only severity >=4
seattle_problems_4 = seattle_problems[seattle_problems['severity'] >= 4]
seattle_problems_4
# Out:
#          username  label_id  street_edge_id            neighborhood  \
# 0    Devon Snyder      8263             519               Greenwood
# 1    Devon Snyder      8264             519               Greenwood
# 3    Devon Snyder      8266             519               Greenwood
# 79   Devon Snyder      8345               6                 Ballard
# 108  Devon Snyder      8374             757              Windermere
# 123  Devon Snyder      8390             302              Queen Anne
# 137  Devon Snyder      8404             275              Queen Anne
# 139  Devon Snyder      8406             301              Queen Anne
# 140  Devon Snyder      8407             301              Queen Anne
# 141  Devon Snyder      8408             301              Queen Anne
# 142  Devon Snyder      8409             301              Queen Anne
# 144  Devon Snyder      8411             301              Queen Anne
# 146  Devon Snyder      8413             301              Queen Anne
# 148  Devon Snyder      8416             300              Queen Anne
# 167  Devon Snyder      8436             277              Queen Anne
# 268  Devon Snyder      8540              87                Delridge
# 326  Devon Snyder      8601             613           Highland Park
# 331  Devon Snyder      8606             613           Highland Park
# 335  Devon Snyder      8610             615           Highland Park
# 336  Devon Snyder      8611             615           Highland Park
# 337  Devon Snyder      8612             615           Highland Park
# 338  Devon Snyder      8613             615           Highland Park
# 340  Devon Snyder      8615             615           Highland Park
# 428         mikey      8843              43                 Ballard
# 463         mikey      8884               6                 Ballard
# 483         mikey      8908              87                Delridge
# 557         mikey      8987             613           Highland Park
# 561         mikey      8992             615           Highland Park
# 569         mikey      9003             582           Highland Park
# 570         mikey      9004             582           Highland Park
# 573         mikey      9007             582           Highland Park
# 612         mikey      9055             189  International District
# 642         mikey      9091             302              Queen Anne
# 646         mikey      9095             302              Queen Anne
# 656         mikey      9106             275              Queen Anne
# 658         mikey      9109             275              Queen Anne
# 665         mikey      9125             300              Queen Anne
# 666         mikey      9126             300              Queen Anne
# 680         mikey      9142             277              Queen Anne
# 688         mikey      9151             277              Queen Anne
# 691         mikey      9154             277              Queen Anne
# 729         mikey      9195            1311     University District
# 730         mikey      9196            1311     University District
# 733         mikey      9199            1311     University District
# 795         mikey      9266             757              Windermere
#
#          label_type        lat         lng         gsv_panorama_id correct  \
# 0          Obstacle  47.697910 -122.346878  eA8O01ruC7m2Hxna2rOYmA    None
# 1          Obstacle  47.697910 -122.346840  eA8O01ruC7m2Hxna2rOYmA    None
# 3          Obstacle  47.697914 -122.346817  -bwvo2vUzCb2YOsT0bKDGQ    None
# 79         Obstacle  47.677937 -122.402039  CTpFmcG_EoiuZibDGbsm1g    None
# 108        Obstacle  47.665848 -122.270592  ejvoKyXM3OaM22knR2uE0w    None
# 123  SurfaceProblem  47.645855 -122.358192  bSDzC_ivz3I9fW_RpO-TLA    None
# 137  SurfaceProblem  47.646854 -122.356972  en_aPYvKeegnvUtw47bNbg    None
# 139  SurfaceProblem  47.645679 -122.358253  jNpQIPe1koWXyGz4g4aHUg    None
# 140  SurfaceProblem  47.645531 -122.358276  xoHROUHOQaf8FiphiwLi0g    None
# 141  SurfaceProblem  47.645477 -122.358261  yTIxSIfO8My54hj_Pp49jA    None
# 142  SurfaceProblem  47.645367 -122.358276  -AxjG4jdel739b-dhP4l4A    None
# 144  SurfaceProblem  47.645363 -122.358200  zJAMndpIEsYjDqF8jm0mig    None
# 146  SurfaceProblem  47.645229 -122.358276  a03PUS_xuRntcMeSiLtY7Q    None
# 148        Obstacle  47.644539 -122.358055  6DuJ1nF3rnVywfTH5eUjhw    None
# 167        Obstacle  47.643322 -122.357201  6pN43Gp-J7S51EI3mRv7gQ    None
# 268        Obstacle  47.549034 -122.368950  nTc0MsFJLdfb6WXJ-6GGpg    None
# 326        Obstacle  47.521069 -122.348320  Gsi_xC3XOYECY_hFGSicaA    None
# 331  SurfaceProblem  47.521038 -122.348114  sXGMt2KNCQ24BoChoMT9ew    None
# 335  SurfaceProblem  47.521065 -122.347382  EldC5PKolPpr7Lkfx7S-VA    None
# 336  SurfaceProblem  47.521030 -122.347252  MZyEfi8wD7jBphgF1O_OoQ    None
# 337  SurfaceProblem  47.521015 -122.347137  aQ-Ld5evO7MVlfUbcwf9YQ    None
# 338  SurfaceProblem  47.521061 -122.346947  nHnd7fgqZntOR51CueerwQ    None
# 340  SurfaceProblem  47.521038 -122.346817  uqJMe7wKCspCw4r7H4qFhQ    None
# 428  SurfaceProblem  47.679359 -122.401993  7k8YFL6tzXzKZRF5l37Dng    None
# 463        Obstacle  47.677952 -122.402054  8EW8huDu4wMBQxM6kmtKXg    None
# 483        Obstacle  47.549034 -122.368942  nTc0MsFJLdfb6WXJ-6GGpg    None
# 557  SurfaceProblem  47.520947 -122.348030  kYZ2x9GPMNzMk9HloQWWXw    None
# 561  SurfaceProblem  47.521065 -122.347374  EldC5PKolPpr7Lkfx7S-VA    None
# 569  SurfaceProblem  47.521614 -122.345764  _mVrIcgsfwiIW9QkWGzybQ    None
# 570  SurfaceProblem  47.521358 -122.345596  EZ9-7fR2GdX5mminfZJr2w    None
# 573  SurfaceProblem  47.521526 -122.345703  2jh3QzTa6N19fCLW0pANhw    None
# 612  SurfaceProblem  47.599976 -122.332214  w7u56GpiQtBTxi5WbdHyyg    None
# 642  SurfaceProblem  47.645920 -122.358231  1NnVCo7fk-3F5xgrDV0KGg    None
# 646  SurfaceProblem  47.646122 -122.358185  80z5g68VLqyUgrUYCC8o-A    None
# 656  SurfaceProblem  47.646961 -122.357391  E5gIKs6WMcAou0fD5jqzsw    None
# 658  SurfaceProblem  47.646854 -122.356964  xV9HJKLkdkDU1MDS591E_g    None
# 665        Obstacle  47.644562 -122.358101  6DuJ1nF3rnVywfTH5eUjhw    None
# 666  SurfaceProblem  47.644520 -122.358162  -JTWTC_DG0cDQIVfM1ESNQ    None
# 680  SurfaceProblem  47.643311 -122.357475  FnLkEWQmrArkCTGQgVfNjA    None
# 688        Obstacle  47.643311 -122.357216  6pN43Gp-J7S51EI3mRv7gQ    None
# 691        Obstacle  47.643173 -122.357018  jMe12GfTIqww0c4GeQFbgw    None
# 729        Obstacle  47.658981 -122.317879  Fea65vl-d0RGQ2f53D4JuA    None
# 730        Obstacle  47.658894 -122.317886  2Lw835iFGvuH_wY_GnAf7g    None
# 733  SurfaceProblem  47.658642 -122.317726  trTHQ5gKhuyYB6QrF0yQlQ    None
# 795        Obstacle  47.665867 -122.270599  oPuBSTkgTXQJTY6vgXPa7Q    None
#
#      severity temporary                                           tag_list  \
# 0           5         t                                               sign
# 1           5         t                                               sign
# 3           5         t                                               sign
# 79          4         f                                         parked car
# 108         4         f                                         parked car
# 123         5         f                                              grass
# 137         4         f                           very broken,grass,cracks
# 139         4         t                                               None
# 140         5         t                                               None
# 141         5         t                                               None
# 142         5         t                                               None
# 144         5         t                                               None
# 146         5         t                                               None
# 148         4         t                                       construction
# 167         5         f                                         parked car
# 268         4         f                          parked scooter/motorcycle
# 326         5         f                                         parked car
# 331         4         f                  grass,narrow sidewalk,very broken
# 335         4         f                        narrow sidewalk,sand/gravel
# 336         4         f                              narrow sidewalk,grass
# 337         4         f                              narrow sidewalk,grass
# 338         4         f                              narrow sidewalk,grass
# 340         4         f                              narrow sidewalk,grass
# 428         4         f                                  height difference
# 463         4         f                                         parked car
# 483         4         f                          parked scooter/motorcycle
# 557         4         f  sand/gravel,utility panel,very broken,height d...
# 561         4         f                        sand/gravel,narrow sidewalk
# 569         4         f                                  height difference
# 570         4         f                   uneven/slanted,height difference
# 573         4         f                                  height difference
# 612         4         f                   uneven/slanted,brick/cobblestone
# 642         4         f                                        bumpy,grass
# 646         4         f                                              bumpy
# 656         4         f                   height difference,uneven/slanted
# 658         4         f                           very broken,grass,cracks
# 665         4         f                                       construction
# 666         4         f                                               None
# 680         4         f            cracks,uneven/slanted,height difference
# 688         5         f                                         parked car
# 691         4         f                                        parked bike
# 729         5         t                                       construction
# 730         5         t                                       construction
# 733         4         f                           cracks,very broken,bumpy
# 795         5         f                                         parked car
#
#                       description                     geometry
# 0                            None  POINT (-122.34688 47.69791)
# 1                            None  POINT (-122.34684 47.69791)
# 3                            None  POINT (-122.34682 47.69791)
# 79                           None  POINT (-122.40204 47.67794)
# 108                          None  POINT (-122.27059 47.66585)
# 123  debris all over the sidewalk  POINT (-122.35819 47.64585)
# 137                          None  POINT (-122.35697 47.64685)
# 139  debris all over the sidewalk  POINT (-122.35825 47.64568)
# 140  debris all over the sidewalk  POINT (-122.35828 47.64553)
# 141  debris all over the sidewalk  POINT (-122.35826 47.64548)
# 142  debris all over the sidewalk  POINT (-122.35828 47.64537)
# 144  debris all over the sidewalk  POINT (-122.35820 47.64536)
# 146  debris all over the sidewalk  POINT (-122.35828 47.64523)
# 148                          None  POINT (-122.35806 47.64454)
# 167                          None  POINT (-122.35720 47.64332)
# 268                          None  POINT (-122.36895 47.54903)
# 326                          None  POINT (-122.34832 47.52107)
# 331                          None  POINT (-122.34811 47.52104)
# 335                          None  POINT (-122.34738 47.52106)
# 336                          None  POINT (-122.34725 47.52103)
# 337                          None  POINT (-122.34714 47.52102)
# 338                          None  POINT (-122.34695 47.52106)
# 340                          None  POINT (-122.34682 47.52104)
# 428                          None  POINT (-122.40199 47.67936)
# 463                          None  POINT (-122.40205 47.67795)
# 483                          None  POINT (-122.36894 47.54903)
# 557                  pooled water  POINT (-122.34803 47.52095)
# 561                          None  POINT (-122.34737 47.52106)
# 569                          None  POINT (-122.34576 47.52161)
# 570                          None  POINT (-122.34560 47.52136)
# 573                          None  POINT (-122.34570 47.52153)
# 612                          None  POINT (-122.33221 47.59998)
# 642                          None  POINT (-122.35823 47.64592)
# 646                         steep  POINT (-122.35818 47.64612)
# 656                          None  POINT (-122.35739 47.64696)
# 658                          None  POINT (-122.35696 47.64685)
# 665                          None  POINT (-122.35810 47.64456)
# 666                        leaves  POINT (-122.35816 47.64452)
# 680                          None  POINT (-122.35748 47.64331)
# 688                          None  POINT (-122.35722 47.64331)
# 691                          None  POINT (-122.35702 47.64317)
# 729                          None  POINT (-122.31788 47.65898)
# 730                          None  POINT (-122.31789 47.65889)
# 733                          None  POINT (-122.31773 47.65864)
# 795                          None  POINT (-122.27060 47.66587)

# %%
alpha_seattle_problems_4 = {}
for i in [2,4,5]:
    alpha = krippendorff_alpha(seattle_problems_4,i, seattle_streets, 2285)
    alpha_seattle_problems_4[label_types[i]] = alpha

# %%
alpha_seattle_problems_4
# Out:
# {'Problem': 0.43, 'SurfaceProblem': 0.294, 'Obstacle': 0.663}

# %% [markdown]
# ### surface problem and obstacle for severity level != 1

# %%
#take out severity ==1
seattle_problems_1 = seattle_problems[seattle_problems['severity'] != 1]
seattle_problems_1
# Out:
#          username  label_id  street_edge_id neighborhood      label_type  \
# 0    Devon Snyder      8263             519    Greenwood        Obstacle
# 1    Devon Snyder      8264             519    Greenwood        Obstacle
# 3    Devon Snyder      8266             519    Greenwood        Obstacle
# 9    Devon Snyder      8273             519    Greenwood  SurfaceProblem
# 12   Devon Snyder      8276             519    Greenwood  SurfaceProblem
# ..            ...       ...             ...          ...             ...
# 787         mikey      9257             785   Windermere        Obstacle
# 792         mikey      9263             757   Windermere  SurfaceProblem
# 795         mikey      9266             757   Windermere        Obstacle
# 797         mikey      9268             757   Windermere  SurfaceProblem
# 798         mikey      9269             757   Windermere  SurfaceProblem
#
#            lat         lng         gsv_panorama_id correct  severity  \
# 0    47.697910 -122.346878  eA8O01ruC7m2Hxna2rOYmA    None         5
# 1    47.697910 -122.346840  eA8O01ruC7m2Hxna2rOYmA    None         5
# 3    47.697914 -122.346817  -bwvo2vUzCb2YOsT0bKDGQ    None         5
# 9    47.697868 -122.346077  rbyOYvxCT3V-yu36bl6H-g    None         2
# 12   47.697758 -122.345909  8_QhZrK8HjNQKU89gRliiw    None         2
# ..         ...         ...                     ...     ...       ...
# 787  47.664925 -122.270256  ZkFu2C_hMTHhDN9zo9J1Xw    None         2
# 792  47.665413 -122.270012  NRu8hHxXG5_brpYK3HoiXw    None         2
# 795  47.665867 -122.270599  oPuBSTkgTXQJTY6vgXPa7Q    None         5
# 797  47.665905 -122.270683  ejvoKyXM3OaM22knR2uE0w    None         3
# 798  47.665894 -122.270668  ejvoKyXM3OaM22knR2uE0w    None         2
#
#     temporary           tag_list description                     geometry
# 0           t               sign        None  POINT (-122.34688 47.69791)
# 1           t               sign        None  POINT (-122.34684 47.69791)
# 3           t               sign        None  POINT (-122.34682 47.69791)
# 9           f             cracks        None  POINT (-122.34608 47.69787)
# 12          f             cracks        None  POINT (-122.34591 47.69776)
# ..        ...                ...         ...                          ...
# 787         f         vegetation        None  POINT (-122.27026 47.66492)
# 792         f             cracks        None  POINT (-122.27001 47.66541)
# 795         f         parked car        None  POINT (-122.27060 47.66587)
# 797         f  height difference        None  POINT (-122.27068 47.66590)
# 798         f             cracks        None  POINT (-122.27067 47.66589)
#
# [257 rows x 14 columns]

# %%
alpha_seattle_problems_1 = {}
for i in [2,4,5]:
    alpha = krippendorff_alpha(seattle_problems_1,i, seattle_streets, 2285)
    alpha_seattle_problems_1[label_types[i]] = alpha

# %%
alpha_seattle_problems_1
# Out:
# {'Problem': 0.572, 'SurfaceProblem': 0.559, 'Obstacle': 0.394}

# %% [markdown]
# ## HTML

# %%
for i in [2,4,5]:
    labels= map_clusters(seattle_problems,i)
    map = seattle_streets.explore(m = labels, tiles="CartoDb DarkMatter", color="#BF616A", style_kwds={"stroke":True,"opacity":0.4,"weight": 2},tooltip=["street_edge_id"])
    map.save("html/seattle_"+label_types[i]+"_round-3_230927.html")

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point
# %matplotlib inline
import seaborn as sns; sns.set_theme(color_codes=True)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors
import warnings
warnings.filterwarnings('ignore')
from scipy import stats
import math    
import folium
from scipy.cluster.hierarchy import linkage, fcluster
from scipy.spatial.distance import pdist
import sys
from haversine import haversine

# %%
labels = pd.read_csv('data/round-1/mikey-devon-labels_validation-221126.csv')

# %%
labels
# Out:
#       Unnamed: 0      username  label_id  street_edge_id         neighborhood  \
# 0              3  Devon Snyder         3             480  University District
# 1              4  Devon Snyder         4             480  University District
# 2              5  Devon Snyder         5             480  University District
# 3              8  Devon Snyder         8             480  University District
# 4              9  Devon Snyder         9             480  University District
# ...          ...           ...       ...             ...                  ...
# 2015        2533  Devon Snyder      2533             479  University District
# 2016        2534  Devon Snyder      2534             479  University District
# 2017        2535  Devon Snyder      2535             479  University District
# 2018        2536  Devon Snyder      2536             479  University District
# 2019        2537  Devon Snyder      2537             479  University District
#
#           label_type        lat         lng         gsv_panorama_id  \
# 0           Obstacle  47.661041 -122.320709  -L8Sgb0ozIqqanCBfAZjYQ
# 1           Obstacle  47.661026 -122.320702  -L8Sgb0ozIqqanCBfAZjYQ
# 2     SurfaceProblem  47.661060 -122.320709  OH4yKYW98UY1aMK_b68Etw
# 3          Occlusion  47.661106 -122.320724  OH4yKYW98UY1aMK_b68Etw
# 4           Obstacle  47.661098 -122.320663  O0VZ-MF6Nrmjhkb2nCRhCw
# ...              ...        ...         ...                     ...
# 2015       Occlusion  47.659710 -122.319855  bWNcSsunJ_MyQcFwru1edg
# 2016  SurfaceProblem  47.659721 -122.319923  SRZ-Py452sb8rEJfkHzHWw
# 2017       Occlusion  47.659653 -122.319908  SRZ-Py452sb8rEJfkHzHWw
# 2018  SurfaceProblem  47.659668 -122.319916  SRZ-Py452sb8rEJfkHzHWw
# 2019       Occlusion  47.659767 -122.319969  SRZ-Py452sb8rEJfkHzHWw
#
#                     time_created correct  severity temporary  \
# 0     2022-05-10 14:00:36.787-07       t       3.0         f
# 1     2022-05-10 14:00:52.367-07       t       2.0         f
# 2     2022-05-10 14:01:21.608-07       t       2.0         f
# 3     2022-05-10 14:02:15.133-07     NaN       NaN         f
# 4     2022-05-10 14:02:29.636-07       t       3.0         f
# ...                          ...     ...       ...       ...
# 2015  2022-11-09 08:08:14.709-08     NaN       NaN         f
# 2016  2022-11-09 08:08:26.318-08     NaN       2.0         f
# 2017  2022-11-09 08:08:36.919-08     NaN       NaN         f
# 2018  2022-11-09 08:08:40.146-08     NaN       2.0         f
# 2019  2022-11-09 08:09:00.991-08     NaN       NaN         f
#
#                    tag_list                    description
# 0                      pole                            NaN
# 1                      pole                            NaN
# 2                     bumpy                            NaN
# 3                       NaN                            NaN
# 4                      sign  temporary due to construction
# ...                     ...                            ...
# 2015                    NaN                            NaN
# 2016  cracks,uneven/slanted                            NaN
# 2017                    NaN                            NaN
# 2018                 cracks                            NaN
# 2019                    NaN                            NaN
#
# [2020 rows x 15 columns]

# %%
#create labels geo dataframe
points = labels.apply(lambda row: Point(row.lng, row.lat), axis=1)
labels_geo = gpd.GeoDataFrame(labels, geometry=points)
labels_geo.crs = {'init': 'epsg:4326'}
labels_geo
# Out:
#       Unnamed: 0      username  label_id  street_edge_id         neighborhood  \
# 0              3  Devon Snyder         3             480  University District
# 1              4  Devon Snyder         4             480  University District
# 2              5  Devon Snyder         5             480  University District
# 3              8  Devon Snyder         8             480  University District
# 4              9  Devon Snyder         9             480  University District
# ...          ...           ...       ...             ...                  ...
# 2015        2533  Devon Snyder      2533             479  University District
# 2016        2534  Devon Snyder      2534             479  University District
# 2017        2535  Devon Snyder      2535             479  University District
# 2018        2536  Devon Snyder      2536             479  University District
# 2019        2537  Devon Snyder      2537             479  University District
#
#           label_type        lat         lng         gsv_panorama_id  \
# 0           Obstacle  47.661041 -122.320709  -L8Sgb0ozIqqanCBfAZjYQ
# 1           Obstacle  47.661026 -122.320702  -L8Sgb0ozIqqanCBfAZjYQ
# 2     SurfaceProblem  47.661060 -122.320709  OH4yKYW98UY1aMK_b68Etw
# 3          Occlusion  47.661106 -122.320724  OH4yKYW98UY1aMK_b68Etw
# 4           Obstacle  47.661098 -122.320663  O0VZ-MF6Nrmjhkb2nCRhCw
# ...              ...        ...         ...                     ...
# 2015       Occlusion  47.659710 -122.319855  bWNcSsunJ_MyQcFwru1edg
# 2016  SurfaceProblem  47.659721 -122.319923  SRZ-Py452sb8rEJfkHzHWw
# 2017       Occlusion  47.659653 -122.319908  SRZ-Py452sb8rEJfkHzHWw
# 2018  SurfaceProblem  47.659668 -122.319916  SRZ-Py452sb8rEJfkHzHWw
# 2019       Occlusion  47.659767 -122.319969  SRZ-Py452sb8rEJfkHzHWw
#
#                     time_created correct  severity temporary  \
# 0     2022-05-10 14:00:36.787-07       t       3.0         f
# 1     2022-05-10 14:00:52.367-07       t       2.0         f
# 2     2022-05-10 14:01:21.608-07       t       2.0         f
# 3     2022-05-10 14:02:15.133-07     NaN       NaN         f
# 4     2022-05-10 14:02:29.636-07       t       3.0         f
# ...                          ...     ...       ...       ...
# 2015  2022-11-09 08:08:14.709-08     NaN       NaN         f
# 2016  2022-11-09 08:08:26.318-08     NaN       2.0         f
# 2017  2022-11-09 08:08:36.919-08     NaN       NaN         f
# 2018  2022-11-09 08:08:40.146-08     NaN       2.0         f
# 2019  2022-11-09 08:09:00.991-08     NaN       NaN         f
#
#                    tag_list                    description  \
# 0                      pole                            NaN
# 1                      pole                            NaN
# 2                     bumpy                            NaN
# 3                       NaN                            NaN
# 4                      sign  temporary due to construction
# ...                     ...                            ...
# 2015                    NaN                            NaN
# 2016  cracks,uneven/slanted                            NaN
# 2017                    NaN                            NaN
# 2018                 cracks                            NaN
# 2019                    NaN                            NaN
#
#                          geometry
# 0     POINT (-122.32071 47.66104)
# 1     POINT (-122.32070 47.66103)
# 2     POINT (-122.32071 47.66106)
# 3     POINT (-122.32072 47.66111)
# 4     POINT (-122.32066 47.66110)
# ...                           ...
# 2015  POINT (-122.31985 47.65971)
# 2016  POINT (-122.31992 47.65972)
# 2017  POINT (-122.31991 47.65965)
# 2018  POINT (-122.31992 47.65967)
# 2019  POINT (-122.31997 47.65977)
#
# [2020 rows x 16 columns]

# %%
# Seperate Seattle and Chicago data
chicago = labels_geo.loc[labels_geo['lng'] > -105]
seattle = labels_geo.loc[labels_geo['lng'] < -105]

# %%
#export to json
# chicago.to_file("data/chicago-validation-labels-round2-230608.geojson", driver='GeoJSON')
# seattle.to_file("data/seattle-validation-labels-round2-230608.geojson", driver='GeoJSON')

# %%
# read in datasets/streets_all_230515.json
streets_validated = gpd.read_file("data/round-1/mikey-devon-streets-round-1.csv")
streets_validated
# Out:
#    route_id region_id street_edge_id     way_type  \
# 0                   9             13  residential
# 1                   9             35  residential
# 2                   9             37  residential
# 3                   9             44     tertiary
# 4                   1             72  residential
# ..      ...       ...            ...          ...
# 76                  3            751  residential
# 77                  3            810  residential
# 78                  3            811  residential
# 79                  7            842  residential
# 80                  3            851      primary
#
#                                                  geom geometry
# 0   0102000020E6100000030000001192600553995EC08DAF...     None
# 1   0102000020E610000002000000D08BC9D152995EC06957...     None
# 2   0102000020E61000000200000017AE580D53995EC0F805...     None
# 3   0102000020E610000003000000836E8A227F995EC0A567...     None
# 4   0102000020E6100000050000002F432D173B975EC059AC...     None
# ..                                                ...      ...
# 76  0102000020E6100000040000001E66D421DC905EC04530...     None
# 77  0102000020E61000000400000063CB97BC26915EC0C5D6...     None
# 78  0102000020E610000002000000D9BDCBFBEE905EC05BBC...     None
# 79  0102000020E610000003000000D5100B6B19915EC01164...     None
# 80  0102000020E61000000200000063CB97BC26915EC0C5D6...     None
#
# [81 rows x 6 columns]

# %%
from shapely import wkb

# %%
# apply wkb.loads(geom, hex=True) to the geom column
streets_validated['geom'] = streets_validated['geom'].apply(lambda x: wkb.loads(x, hex=True))
streets_validated
# Out:
#    route_id region_id street_edge_id     way_type  \
# 0                   9             13  residential
# 1                   9             35  residential
# 2                   9             37  residential
# 3                   9             44     tertiary
# 4                   1             72  residential
# ..      ...       ...            ...          ...
# 76                  3            751  residential
# 77                  3            810  residential
# 78                  3            811  residential
# 79                  7            842  residential
# 80                  3            851      primary
#
#                                                  geom geometry
# 0   LINESTRING (-122.3956922 47.6773064, -122.3963...     None
# 1   LINESTRING (-122.3956799 47.6765936, -122.3956...     None
# 2   LINESTRING (-122.3956941 47.6758792, -122.3956...     None
# 3   LINESTRING (-122.3983847 47.677293, -122.39839...     None
# 4   LINESTRING (-122.3629816 47.5501056, -122.3628...     None
# ..                                                ...      ...
# 76  LINESTRING (-122.2634358 47.6684541, -122.2634...     None
# 77  LINESTRING (-122.2679893 47.6722212, -122.2677...     None
# 78  LINESTRING (-122.2645864 47.6721052, -122.2635...     None
# 79  LINESTRING (-122.2671764 47.5415918, -122.2657...     None
# 80  LINESTRING (-122.2679893 47.6722212, -122.2681...     None
#
# [81 rows x 6 columns]

# %%
# create streets geo dataframe
streets_validated = gpd.GeoDataFrame(streets_validated, geometry='geom')
streets_validated.crs = {'init': 'epsg:4326'}
streets_validated.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3aff77914f14490f6a2e410ed5498683 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3aff77914f14490f6a2e410ed5498683&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3aff77914f14490f6a2e410ed5498683 = L.map(
#                 &quot;map_3aff77914f14490f6a2e410ed5498683&quot;,
#                 {
#                     center: [44.6687275, -105.0100698],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3aff77914f14490f6a2e410ed5498683);
#
#
#
#
#
#             var tile_layer_c58895f7e18ef3ba360b88968a83e58c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3aff77914f14490f6a2e410ed5498683);
#
#
#             map_3aff77914f14490f6a2e410ed5498683.fitBounds(
#                 [[41.6405434, -122.3983959], [47.6969116, -87.6217437]],
#                 {}
#             );
#
#
#         function geo_json_03ee16ba3d90e6ebc8b89399af732cbd_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_03ee16ba3d90e6ebc8b89399af732cbd_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_03ee16ba3d90e6ebc8b89399af732cbd_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_03ee16ba3d90e6ebc8b89399af732cbd_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_03ee16ba3d90e6ebc8b89399af732cbd_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_03ee16ba3d90e6ebc8b89399af732cbd.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_03ee16ba3d90e6ebc8b89399af732cbd_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_03ee16ba3d90e6ebc8b89399af732cbd = L.geoJson(null, {
#                 onEachFeature: geo_json_03ee16ba3d90e6ebc8b89399af732cbd_onEachFeature,
#
#                 style: geo_json_03ee16ba3d90e6ebc8b89399af732cbd_styler,
#                 pointToLayer: geo_json_03ee16ba3d90e6ebc8b89399af732cbd_pointToLayer
#         });
#
#         function geo_json_03ee16ba3d90e6ebc8b89399af732cbd_add (data) {
#             geo_json_03ee16ba3d90e6ebc8b89399af732cbd
#                 .addData(data)
#                 .addTo(map_3aff77914f14490f6a2e410ed5498683);
#         }
#             geo_json_03ee16ba3d90e6ebc8b89399af732cbd_add({&quot;bbox&quot;: [-122.3983959, 41.6405434, -87.6217437, 47.6969116], &quot;features&quot;: [{&quot;bbox&quot;: [-122.3983847, 47.677293, -122.3956922, 47.6773064], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.3956922, 47.6773064], [-122.3963386, 47.6773032], [-122.3983847, 47.677293]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;region_id&quot;: &quot;9&quot;, &quot;route_id&quot;: &quot;&quot;, &quot;street_edge_id&quot;: &quot;13&quot;, &quot;way_type&quot;: &quot;residential&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-122.3956922, 47.6765936, -122.3956799, 47.6773064], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.3956799, 47.6765936], [-122.3956922, 47.6773064]], &quot;type&quot;: &quot;LineString

# %%
#seperate seattle and chicago based on geometry, chicago >-105 and < -80, seattle < -105
streets_chicago = streets_validated.loc[streets_validated['geom'].bounds['minx'] > -105]
streets_chicago = streets_chicago.loc[streets_chicago['geom'].bounds['minx'] < -80]
streets_seattle = streets_validated.loc[streets_validated['geom'].bounds['minx'] < -105]

# %%
chicago
# Out:
#       Unnamed: 0      username  label_id  street_edge_id neighborhood  \
# 76            94  Devon Snyder        94             447       Skokie
# 77            96  Devon Snyder        96             447       Skokie
# 78            97  Devon Snyder        97             437       Skokie
# 79            98  Devon Snyder        98             437       Skokie
# 80            99  Devon Snyder        99             447       Skokie
# ...          ...           ...       ...             ...          ...
# 1900        2386         mikey      2386             447       Skokie
# 1901        2387         mikey      2387             447       Skokie
# 1902        2388         mikey      2388             447       Skokie
# 1903        2389         mikey      2389             447       Skokie
# 1904        2390         mikey      2390             447       Skokie
#
#           label_type        lat        lng         gsv_panorama_id  \
# 76          CurbRamp  42.022606 -87.728157  rcjtiNG8gkNtkifZDFj2NQ
# 77          CurbRamp  42.022720 -87.728149  rcjtiNG8gkNtkifZDFj2NQ
# 78          CurbRamp  42.022717 -87.728432  _KrmBjHlebAncoZc40tsSg
# 79          CurbRamp  42.022621 -87.728439  _KrmBjHlebAncoZc40tsSg
# 80    SurfaceProblem  42.022999 -87.728149  2vMz67hXm2ZGNcKHbyoR8g
# ...              ...        ...        ...                     ...
# 1900  SurfaceProblem  42.024151 -87.728142  AAY7v8bGlzT1XFHSxQ_jKQ
# 1901        CurbRamp  42.023594 -87.728142  tagGeC6m-TMnzcfHLPX6Hg
# 1902        CurbRamp  42.023453 -87.728127  TdCToHEwW86oaUfwfNNDaw
# 1903        CurbRamp  42.022594 -87.728149  rcjtiNG8gkNtkifZDFj2NQ
# 1904        CurbRamp  42.022709 -87.728149  rcjtiNG8gkNtkifZDFj2NQ
#
#                     time_created correct  severity temporary  \
# 76    2022-05-10 14:56:14.398-07       t       4.0         f
# 77    2022-05-10 14:56:58.603-07       t       3.0         f
# 78    2022-05-10 14:57:43.381-07       t       3.0         f
# 79    2022-05-10 14:58:11.132-07       t       3.0         f
# 80    2022-05-10 14:59:05.467-07       t       1.0         f
# ...                          ...     ...       ...       ...
# 1900  2022-07-05 12:41:31.117-07     NaN       1.0         f
# 1901  2022-07-05 12:41:55.266-07     NaN       1.0         f
# 1902  2022-07-05 12:42:00.438-07     NaN       1.0         f
# 1903  2022-07-05 12:42:51.976-07     NaN       1.0         f
# 1904  2022-07-05 12:42:56.272-07     NaN       2.0         f
#
#                                                tag_list description  \
# 76    not enough landing space,narrow,not level with...         NaN
# 77             not enough landing space,surface problem         NaN
# 78         not enough landing space,points into traffic         NaN
# 79                             not enough landing space         NaN
# 80                                                grass         NaN
# ...                                                 ...         ...
# 1900                                              grass         NaN
# 1901                                                NaN         NaN
# 1902                                                NaN         NaN
# 1903                                                NaN         NaN
# 1904                                    surface problem         NaN
#
#                         geometry
# 76    POINT (-87.72816 42.02261)
# 77    POINT (-87.72815 42.02272)
# 78    POINT (-87.72843 42.02272)
# 79    POINT (-87.72844 42.02262)
# 80    POINT (-87.72815 42.02300)
# ...                          ...
# 1900  POINT (-87.72814 42.02415)
# 1901  POINT (-87.72814 42.02359)
# 1902  POINT (-87.72813 42.02345)
# 1903  POINT (-87.72815 42.02259)
# 1904  POINT (-87.72815 42.02271)
#
# [547 rows x 16 columns]

# %%
base = streets_chicago.explore( tiles='cartodbpositron', color='red')

# %%
base_2 = streets_seattle.explore( tiles='cartodbpositron', color='red')

# %%
test = chicago.explore(m= base, color='blue', tiles='cartodbpositron')

# %%
test_2 = seattle.explore(m= base_2, color='blue', tiles='cartodbpositron')

# %%
test_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06d52fc714bf43c84cd06b48e532b52a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06d52fc714bf43c84cd06b48e532b52a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_06d52fc714bf43c84cd06b48e532b52a = L.map(
#                 &quot;map_06d52fc714bf43c84cd06b48e532b52a&quot;,
#                 {
#                     center: [47.60893555, -122.3309107],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_06d52fc714bf43c84cd06b48e532b52a);
#
#
#
#
#
#             var tile_layer_cb0f4aeb0170309f74fcbf827c4875ab = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_06d52fc714bf43c84cd06b48e532b52a);
#
#
#             map_06d52fc714bf43c84cd06b48e532b52a.fitBounds(
#                 [[47.5209595, -122.3983959], [47.6969116, -122.2634255]],
#                 {}
#             );
#
#
#         function geo_json_99da89a74c11c8618827a2a02df3f921_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_99da89a74c11c8618827a2a02df3f921_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_99da89a74c11c8618827a2a02df3f921_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_99da89a74c11c8618827a2a02df3f921_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_99da89a74c11c8618827a2a02df3f921_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_99da89a74c11c8618827a2a02df3f921.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_99da89a74c11c8618827a2a02df3f921_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_99da89a74c11c8618827a2a02df3f921 = L.geoJson(null, {
#                 onEachFeature: geo_json_99da89a74c11c8618827a2a02df3f921_onEachFeature,
#
#                 style: geo_json_99da89a74c11c8618827a2a02df3f921_styler,
#                 pointToLayer: geo_json_99da89a74c11c8618827a2a02df3f921_pointToLayer
#         });
#
#         function geo_json_99da89a74c11c8618827a2a02df3f921_add (data) {
#             geo_json_99da89a74c11c8618827a2a02df3f921
#                 .addData(data)
#                 .addTo(map_06d52fc714bf43c84cd06b48e532b52a);
#         }
#             geo_json_99da89a74c11c8618827a2a02df3f921_add({&quot;bbox&quot;: [-122.3983959, 47.5209595, -122.2634255, 47.6969116], &quot;features&quot;: [{&quot;bbox&quot;: [-122.3983847, 47.677293, -122.3956922, 47.6773064], &qu

# %%
test.save('chicago_round_1_230609_evening.html')

# %%
test_2.save('seattle_round_1_230609_evening.html')

# %%
#save to geojson
streets_chicago.to_file("data/chicago-streets-230608.geojson", driver='GeoJSON')
streets_seattle.to_file("data/seattle-streets-230608.geojson", driver='GeoJSON')
